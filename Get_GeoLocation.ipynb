# %%
import pandas as pd
import requests

def get_geolocation(api_key, location):
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {
        'address': location,
        'key': api_key,
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        print(f"Error: {data['status']}")
        return None

api_key = 'API_KEY'

file_path = 'Copy of Bioscience Map of Maine company-town (2).xlsx'  
sheet_name = 'Colleges'  
column_name = 'Colleges'  

df = pd.read_excel(file_path, sheet_name=sheet_name)

for index, row in df.iterrows():
    institution_name = row[column_name]
    location = get_geolocation(api_key, institution_name)

    if location:
        print(f"{institution_name}: Latitude - {location[0]}, Longitude - {location[1]}")
# Out:
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Error: REQUEST_DENIED
# Maine College of Art: Latitude - 43.6556992, Longitude - -70.2605967
# Maine College of Health Professions: Latitude - 44.1004877, Longitude - -70.21756169999999
# Maine Maritime Academy: Latitude - 44.3885883, Longitude - -68.803489
# Maine Media College: Latitude - 44.1934233, Longitude - -69.0762742
# Maine Theological Seminary: Latitude - 45.253783, Longitude - -69.4454689
# New England Bible College: Latitude - 43.6244501, Longitude - -70.2514734
# Error: REQUEST_DENIED
# Error: ZERO_RESULTS
# Saint Joseph's College: Latitude - 43.8263596, Longitude - -70.4833458
# Salt Institute for Documentary Studies: Latitude - 43.6556882, Longitude - -70.2608199
# Southern New Hampshire University - Brunswick/Winter Harbor: Latitude - 44.3947873, Longitude - -68.0830278
# Thomas College: Latitude - 44.5247619, Longitude - -69.6631426
# Unity College: Latitude - 43.9057582, Longitude - -70.2570914
# Error: REQUEST_DENIED
# University of Maine at Augusta: Latitude - 44.3379097, Longitude - -69.7965122
# University of Maine at Farmington: Latitude - 44.901867, Longitude - -68.66882509999999
# University of Maine at Fort Kent: Latitude - 47.2503932, Longitude - -68.58930219999999
# Error: REQUEST_DENIED
# University of Maine at Presque Isle: Latitude - 46.6700959, Longitude - -68.0158878
# University of Maine Cooperative Extension: Latitude - 44.901867, Longitude - -68.66882509999999
# University of Maine System: Latitude - 44.6675867, Longitude - -70.14744089999999
# University of New England: Latitude - 43.4582904, Longitude - -70.3865402
# University of Southern Maine - Portland: Latitude - 43.6619019, Longitude - -70.2757206

# %%
import pandas as pd
import requests

def get_geolocation(api_key, location):
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {
        'address': location,
        'key': api_key,
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        print(f"Error: {data['status']}")
        return None


api_key = 'API_KEY'

file_path = 'Copy of Bioscience Map of Maine company-town (2).xlsx' 
sheet_name = 'Colleges'  
column_name = 'Colleges'  

df = pd.read_excel(file_path, sheet_name=sheet_name)

for index, row in df.iterrows():
    institution_name = row[column_name]
    latitude = row['Latitude']
    longitude = row['Longitude']

    if pd.isnull(latitude) or pd.isnull(longitude):
        print(f"Filling geolocation for: {institution_name}")

        location = get_geolocation(api_key, institution_name)

        if location:
            print(f"{institution_name}: Latitude - {location[0]}, Longitude - {location[1]}")
            df.at[index, 'Latitude'] = location[0]
            df.at[index, 'Longitude'] = location[1]
        else:
            print(f"Failed to get geolocation for: {institution_name}")

df.to_excel(file_path, sheet_name=sheet_name, index=False)
# Out:
# Filling geolocation for: Bates College
# Bates College: Latitude - 44.1057216, Longitude - -70.2021865
# Filling geolocation for: Beal College
# Beal College: Latitude - 44.7862579, Longitude - -68.78545869999999
# Filling geolocation for: Bowdoin College
# Bowdoin College: Latitude - 43.9076929, Longitude - -69.9639971
# Filling geolocation for: Colby College
# Colby College: Latitude - 44.5638691, Longitude - -69.6626362
# Filling geolocation for: College of the Atlantic
# College of the Atlantic: Latitude - 44.3950271, Longitude - -68.2215194
# Filling geolocation for: Heartwood College of Art
# Heartwood College of Art: Latitude - 43.4933568, Longitude - -70.4511971
# Filling geolocation for: Husson University
# Husson University: Latitude - 44.8277943, Longitude - -68.7936927
# Filling geolocation for: Maine College of Art
# Maine College of Art: Latitude - 43.6556992, Longitude - -70.2605967
# Filling geolocation for: Maine College of Health Professions
# Maine College of Health Professions: Latitude - 44.1004877, Longitude - -70.21756169999999
# Filling geolocation for: Maine Maritime Academy
# Maine Maritime Academy: Latitude - 44.3885883, Longitude - -68.803489
# Filling geolocation for: Maine Media College
# Maine Media College: Latitude - 44.1934233, Longitude - -69.0762742
# Filling geolocation for: Maine Theological Seminary
# Maine Theological Seminary: Latitude - 45.253783, Longitude - -69.4454689
# Filling geolocation for: New England Bible College
# New England Bible College: Latitude - 43.6244501, Longitude - -70.2514734
# Filling geolocation for: New England School of Communications
# New England School of Communications: Latitude - 44.8289011, Longitude - -68.7929084
# Filling geolocation for: Purdue Global University
# Error: ZERO_RESULTS
# Failed to get geolocation for: Purdue Global University
# Filling geolocation for: Saint Joseph's College
# Saint Joseph's College: Latitude - 43.8263596, Longitude - -70.4833458
# Filling geolocation for: Salt Institute for Documentary Studies
# Salt Institute for Documentary Studies: Latitude - 43.6556882, Longitude - -70.2608199
# Filling geolocation for: Southern New Hampshire University - Brunswick/Winter Harbor
# Southern New Hampshire University - Brunswick/Winter Harbor: Latitude - 44.3947873, Longitude - -68.0830278
# Filling geolocation for: Thomas College
# Thomas College: Latitude - 44.5247619, Longitude - -69.6631426
# Filling geolocation for: Unity College
# Unity College: Latitude - 43.9057582, Longitude - -70.2570914
# Filling geolocation for: University of Maine - Orono
# University of Maine - Orono: Latitude - 44.901867, Longitude - -68.66882509999999
# Filling geolocation for: University of Maine at Augusta
# University of Maine at Augusta: Latitude - 44.3379097, Longitude - -69.7965122
# Filling geolocation for: University of Maine at Farmington
# University of Maine at Farmington: Latitude - 44.901867, Longitude - -68.66882509999999
# Filling geolocation for: University of Maine at Fort Kent
# University of Maine at Fort Kent: Latitude - 47.2503932, Longitude - -68.58930219999999
# Filling geolocation for: University of Maine at Machias
# University of Maine at Machias: Latitude - 44.7080638, Longitude - -67.45610789999999
# Filling geolocation for: University of Maine at Presque Isle
# University of Maine at Presque Isle: Latitude - 46.6700959, Longitude - -68.0158878
# Filling geolocation for: University of Maine Cooperative Extension
# University of Maine Cooperative Extension: Latitude - 44.901867, Longitude - -68.66882509999999
# Filling geolocation for: University of Maine System
# University of Maine System: Latitude - 44.6675867, Longitude - -70.14744089999999
# Filling geolocation for: University of New England
# University of New England: Latitude - 43.4582904, Longitude - -70.3865402
# Filling geolocation for: University of Southern Maine - Portland
# University of Southern Maine - Portland: Latitude - 43.6619019, Longitude - -70.2757206
